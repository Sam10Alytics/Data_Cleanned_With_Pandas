# %% [markdown]
# ## EXTRACTION

# %%
import pandas as pd

# %%
travels_data = pd.read_csv('https://drive.google.com/uc?id=1muwnik-uFGTKBdHmcQN5z68rD7qmdG-b')

# %%
travels_data.shape
# Out:
# (418, 6)

# %%
travels_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    object
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 19.7+ KB

# %%
travels_data
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD   2017-11-06           2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel
# 0                   644.10        Conference
# 1                  2962.70        Conference
# 2                  1891.19        Conference
# 3                   324.36        Conference
# 4                  2141.51        Conference
# ..                     ...               ...
# 413                 502.45        Conference
# 414                  78.00        Conference
# 415                 567.00        Conference
# 416                2163.67        Conference
# 417                2107.51        Conference
#
# [418 rows x 6 columns]

# %%
travels_data.drop_duplicates()
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD   2017-11-06           2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel
# 0                   644.10        Conference
# 1                  2962.70        Conference
# 2                  1891.19        Conference
# 3                   324.36        Conference
# 4                  2141.51        Conference
# ..                     ...               ...
# 413                 502.45        Conference
# 414                  78.00        Conference
# 415                 567.00        Conference
# 416                2163.67        Conference
# 417                2107.51        Conference
#
# [418 rows x 6 columns]

# %% [markdown]
# ## CLEANING

# %%
travels_dataset['Travel Start Date'] = pd.to_datetime(travels_dataset['Travel Start Date'])

# %%
travels_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 19.7+ KB

# %%
## To create copy in python

# %%
travels_dataset = travels_data.copy()

# %%
type(travels_data['Travel Start Date'][0])
# Out:
# str

# %%
travels_data['Travel Start Date'] = pd.to_datetime(travels_data['Travel Start Date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 travels_data['Travel Start Date'] = pd.to_datetime(travels_data['Travel Start Date'])
#
# File e:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File e:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File e:\Users\lenovo\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:359, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains when parsing with format "%Y-%m-%d": "     ", at position 413. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
def remove_white_space(text):
   if type(text) == str:
      return text.strip()
   return text

# %%
travels_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 19.7+ KB

# %%
travels_dataset['Travel Start Date'] = travels_dataset['Travel Start Date'].apply(remove_white_space)

# %%
travels_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    object
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 19.7+ KB

# %%
travels_dataset['Travele End  Date'] = travels_dataset['Travel End Date'].apply(remove_white_space)
travels_dataset['Travel End Date'] = pd.to_datetime(travels_dataset['Travel End Date'])

# %%
travels_dataset.shape
# Out:
# (418, 7)

# %%
travels_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    datetime64[ns]
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      415 non-null    object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 19.7+ KB

# %%
travels_dataset # check that the changes were applied
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD        2017-11-06      2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel Travele End  Date
# 0                   644.10        Conference        2017-06-02
# 1                  2962.70        Conference        2016-01-29
# 2                  1891.19        Conference        2018-10-09
# 3                   324.36        Conference        2016-06-21
# 4                  2141.51        Conference        2019-11-22
# ..                     ...               ...               ...
# 413                 502.45        Conference        2017-11-09
# 414                  78.00        Conference        2019-03-26
# 415                 567.00        Conference        2017-11-09
# 416                2163.67        Conference        2017-05-26
# 417                2107.51        Conference        2019-08-17
#
# [418 rows x 7 columns]

# %%
travels_dataset[travels_dataset['Purpose Of Travel'].isna()]  # check for the row for null value
# Out:
#              Employee     Destination Travel Start Date Travel End Date  \
# 126     Gaila Compton  OCEAN CITY, MD        2019-09-25      2019-09-27
# 274      Mark Sheelor   LAS VEGAS, NV        2017-03-06      2017-03-08
# 385  Tamara Maldonado  OCEAN CITY, MD        2017-10-19      2017-10-20
#
#      Actual Total Expenses Purpose Of Travel Travele End  Date
# 126                 690.00               NaN        2019-09-27
# 274                1411.34               NaN        2017-03-08
# 385                  73.50               NaN        2017-10-20

# %%
travels_dataset['Purpose Of Travel'] = travels_dataset['Purpose Of Travel'] .fillna('not provided') # change non null to not provided

# %%
travels_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    datetime64[ns]
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      418 non-null    object
#  6   Travele End  Date      418 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), object(3)
# memory usage: 23.0+ KB

# %%
travels_dataset  # check that the changes were applied
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD        2017-11-06      2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel Travele End  Date
# 0                   644.10        Conference        2017-06-02
# 1                  2962.70        Conference        2016-01-29
# 2                  1891.19        Conference        2018-10-09
# 3                   324.36        Conference        2016-06-21
# 4                  2141.51        Conference        2019-11-22
# ..                     ...               ...               ...
# 413                 502.45        Conference        2017-11-09
# 414                  78.00        Conference        2019-03-26
# 415                 567.00        Conference        2017-11-09
# 416                2163.67        Conference        2017-05-26
# 417                2107.51        Conference        2019-08-17
#
# [418 rows x 7 columns]

# %%
""" extract state"""

def extract_state(text):
    result = text.split(',')[1]
    return result


""" extract scity"""

def extract_city(text):
    result = text.split(',')[0]
    return result

# %%
# extract state and city fom destination
travels_dataset['state'] = travels_dataset['Destination'].apply(extract_state)
travels_dataset['city'] = travels_dataset['Destination'].apply(extract_city)

# %%
travels_dataset.info() # check that the changes were applied
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee               418 non-null    object
#  1   Destination            418 non-null    object
#  2   Travel Start Date      418 non-null    datetime64[ns]
#  3   Travel End Date        418 non-null    datetime64[ns]
#  4   Actual Total Expenses  418 non-null    float64
#  5   Purpose Of Travel      418 non-null    object
#  6   Travele End  Date      418 non-null    datetime64[ns]
#  7   state                  418 non-null    object
#  8   city                   418 non-null    object
# dtypes: datetime64[ns](3), float64(1), object(5)
# memory usage: 29.5+ KB

# %%
travels_dataset # check that the changes were applied
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD        2017-11-06      2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel Travele End  Date state  \
# 0                   644.10        Conference        2017-06-02    MD
# 1                  2962.70        Conference        2016-01-29    CA
# 2                  1891.19        Conference        2018-10-09    FL
# 3                   324.36        Conference        2016-06-21    MD
# 4                  2141.51        Conference        2019-11-22    CA
# ..                     ...               ...               ...   ...
# 413                 502.45        Conference        2017-11-09    MD
# 414                  78.00        Conference        2019-03-26    MD
# 415                 567.00        Conference        2017-11-09    MD
# 416                2163.67        Conference        2017-05-26    NC
# 417                2107.51        Conference        2019-08-17    MD
#
#            city
# 0    OCEAN CITY
# 1     SAN DIEGO
# 2       ORLANDO
# 3    OCEAN CITY
# 4     SAN DIEGO
# ..          ...
# 413  OCEAN CITY
# 414  OCEAN CITY
# 415  OCEAN CITY
# 416   CHARLOTTE
# 417  OCEAN CITY
#
# [418 rows x 9 columns]

# %%
travels_dataset # check that the changes were applied
# Out:
#               Employee     Destination Travel Start Date Travel End Date  \
# 0         Aaron Salter  OCEAN CITY, MD        2017-05-31      2017-06-02
# 1    Abigail Ratnofsky   SAN DIEGO, CA        2016-01-24      2016-01-29
# 2       Adam Kisthardt     ORLANDO, FL        2018-10-04      2018-10-09
# 3        Adam P. Jones  OCEAN CITY, MD        2016-06-19      2016-06-21
# 4          Alan Butsch   SAN DIEGO, CA        2019-11-19      2019-11-22
# ..                 ...             ...               ...             ...
# 413     Warren Jensen!  OCEAN CITY, MD        2017-11-06      2017-11-09
# 414        Warp Jensen  OCEAN CITY, MD        2019-03-25      2019-03-26
# 415     Whitney Kujawa  OCEAN CITY, MD        2017-11-06      2017-11-09
# 416      William Kinna   CHARLOTTE, NC        2017-05-21      2017-05-26
# 417             Xin Qi  OCEAN CITY, MD        2019-08-13      2019-08-17
#
#      Actual Total Expenses Purpose Of Travel Travele End  Date state  \
# 0                   644.10        Conference        2017-06-02    MD
# 1                  2962.70        Conference        2016-01-29    CA
# 2                  1891.19        Conference        2018-10-09    FL
# 3                   324.36        Conference        2016-06-21    MD
# 4                  2141.51        Conference        2019-11-22    CA
# ..                     ...               ...               ...   ...
# 413                 502.45        Conference        2017-11-09    MD
# 414                  78.00        Conference        2019-03-26    MD
# 415                 567.00        Conference        2017-11-09    MD
# 416                2163.67        Conference        2017-05-26    NC
# 417                2107.51        Conference        2019-08-17    MD
#
#            city lname       fname
# 0    OCEAN CITY    MD  OCEAN CITY
# 1     SAN DIEGO    CA   SAN DIEGO
# 2       ORLANDO    FL     ORLANDO
# 3    OCEAN CITY    MD  OCEAN CITY
# 4     SAN DIEGO    CA   SAN DIEGO
# ..          ...   ...         ...
# 413  OCEAN CITY    MD  OCEAN CITY
# 414  OCEAN CITY    MD  OCEAN CITY
# 415  OCEAN CITY    MD  OCEAN CITY
# 416   CHARLOTTE    NC   CHARLOTTE
# 417  OCEAN CITY    MD  OCEAN CITY
#
# [418 rows x 11 columns]
